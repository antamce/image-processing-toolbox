# %% [markdown]
# # Examples

# %%
#batch analyze tiff stacks
from pathlib import Path
from analyze import analyze_tiff_stack

path = str(Path("C:\\Users\\user\\Desktop"))
analyze_tiff_stack(path, 'control', 0.025, 0.2, "C:\\Users\\user\\Desktop")

# %%
#batch analyze singular tiffs
from pathlib import Path
from analyze import analyze_tiff

path = str(Path("C:\\Users\\user\\Desktop"))
resolution, SNR, fwhm = analyze_tiff(path, 'control', 0.025, 0.2, "C:\\Users\\user\\Desktop")

# %%
#compare singular tiffs
from pathlib import Path
from analyze import compare_tiffs

path = str(Path("C:\\Users\\user\\Desktop"))
ssim, rmse = compare_tiffs(path, path, str(Path('C:\\Users\\user\\Desktop')))
print(ssim)
print(rmse)
# Out:
# 0
# 1.0
# 0.0

# %%
#reslice image
from reslice_tif import reslice_image
from pathlib import Path
path = str(Path("C:\\Users\\user\\Desktop\\my_tif.tif"))
xy, xz, yz = reslice_image(path, save=True, output_path=str(Path('C:\\Users\\user\\Desktop')))

# %%
#colourmap reference

'''
                        0 : Autumn,
                        1 : Bone,
                        2 : Jet,
                        3 : Winter,
                        4 : Rainbow,
                        5 : Ocean,
                        6 : Summer,
                        7 : Spring,
                        8 : Cool,
                        9 : Hsv,
                        10 : Pink,
                        11 : Hot,
                        12  : Parula,
                        13 : Magma,
                        14 : Inferno,
                        15 : Plasma,
                        16 : Viridis,
                        17 : Cividis,
                        18 : Twilight,
                        19 : Twilight_Shifted,
                        20 : Turbo,
                        21 : Deepgreen

'''
